# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahnazshamissa/Python/blob/main/Seaborn_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline# output the plots directly into the Jupyter Notebook
import matplotlib.pyplot as plt
# Out:
# UsageError: unrecognized arguments: output the plots directly into the Jupyter Notebook

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=['Mercury', 'Venus', 'Earth'])
df.plot.pie(y='mass', figsize=(5, 5))

# %%
df.plot.pie(y='mass', figsize=(10, 10))

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")
pd.set_option("display.max.columns", None) # ask Pandas not to hide columns in case there are many columns
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# ...

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"]) # omitted  kind='line' as this is the default value

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"], kind='area')

# %%
df.plot(x="Rank", y="P75th")

# %%
df.Median.plot(kind="bar")

# %%
df.Median.plot(kind="area")

# %%
ax_h = df.Median.plot(kind="hist")
df.Median.plot(kind='kde', ax=ax_h, secondary_y=True)

# %%
# Violin plot
sns.violinplot(x=df.Median);
# visualizes distribution and its probability density
# the median is the WHITE DOT in the middle

# for the rest - read here https://datavizcatalogue.com/methods/violin_plot.html

# %%
df.Median.plot(kind='box')
# draws a line for the median
# a box around the 25 and 75 percentiles

# %%
df.plot(kind='box', subplots=True, layout=(3,7))# we can apply a box plot on the full datafram
# Out:
# Rank                       AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# Major_code              AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# Total                   AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# Men                     AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# Women                   AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# ShareWomen              AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# Sample_size             AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# Employed                   AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# Full_time               AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# Part_time               AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# Full_time_year_round    AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# Unemployed              AxesSubplot(0.578659,0.391471;0.0945122x0.222059)
# Unemployment_rate       AxesSubplot(0.692073,0.391471;0.0945122x0.222059)
# ...

# %%
df.plot(kind='box', subplots=True, layout=(3,7)); # the semicolon at the end hides matplotlib's messages

# %%
df.plot(kind='box', subplots=True, layout=(3,7), figsize=(50, 30)); # we can apply a box plot on the full datafram

# %%
## Checking for correlation
df.plot(x="Median", y="Unemployment_rate", kind="scatter");

# %%
df.plot(x="Median", y="Unemployment_rate", kind="hexbin"); # the deeper the colour, the higher the density

# %%
sns.violinplot(x='Median', y='Unemployment_rate', data = df);

# %%
## checking for correlations again
corr = df.corr()
corr
# Out:
#                           Rank  Major_code     Total       Men     Women  \
# Rank                  1.000000    0.108429  0.071137 -0.094780  0.174913
# Major_code            0.108429    1.000000  0.196784  0.179299  0.181459
# Total                 0.071137    0.196784  1.000000  0.878088  0.944764
# Men                  -0.094780    0.179299  0.878088  1.000000  0.672759
# Women                 0.174913    0.181459  0.944764  0.672759  1.000000
# ShareWomen            0.643781    0.259211  0.142999 -0.112014  0.297832
# Sample_size           0.008492    0.206580  0.945575  0.875176  0.862606
# Employed              0.070751    0.200925  0.996214  0.870605  0.944037
# Full_time             0.034725    0.199397  0.989339  0.893563  0.917681
# Part_time             0.193174    0.195184  0.950268  0.751592  0.954513
# Full_time_year_round  0.020418    0.205634  0.981112  0.892454  0.905720
# Unemployed            0.090078    0.223418  0.974768  0.869411  0.911694
# ...

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# # **Honorable Mention**

# %%
dataset = 'https://raw.githubusercontent.com/albertsl/datasets/master/popularidad/temporal.csv' # link to more info about the data https://towardsdatascience.com/complete-guide-to-data-visualization-with-python-2dd74df12b5e
df = pd.read_csv(dataset)
df['Mes'] = pd.to_datetime(df['Mes'])
df.head()
# Out:
#          Mes  data science  machine learning  deep learning  categorical
# 0 2004-01-01            12                18              4            1
# 1 2004-02-01            12                21              2            1
# 2 2004-03-01             9                21              2            1
# 3 2004-04-01            10                16              4            1
# 4 2004-05-01             7                14              3            1

# %%
format_dict = {'data science':'${0:,.2f}', 'Mes':'{:%m-%Y}', 'machine learning':'{:.2%}'}
df.head(10).style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_3d22bb9c_149c_11eb_abd3_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mes</th>        <th class="col_heading level0 col1" >data science</th>        <th class="col_heading level0 col2" >machine learning</th>        <th class="col_heading level0 col3" >deep learning</th>        <th class="col_heading level0 col4" >categorical</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d22bb9c_149c_11eb_abd3_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3d22bb9c_149c_11eb_abd3_0242ac1c0002row0_col0" class="data row0 col0" >01-2004</td>
#                         <td id="T_3d22bb9c_149c_11eb_abd3_0242ac1c0002row0_col1" class="data row0 col1" >$12.00</td>
#                         <td id="T_3d22bb9c_149c_11eb_abd3_0242ac1c0002row0_col2" class="data row0 col2" >1800.00%</td>
# ...

# %%
df.head(10).style.format(format_dict).highlight_max(color='darkgreen').highlight_min(color='#ff0000')
# Out:
# <style  type="text/css" >
# #T_4e3deece_149c_11eb_abd3_0242ac1c0002row0_col1,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row0_col3,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row1_col1,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row1_col2,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row2_col2,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row3_col3,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row8_col3,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row9_col3{
#             background-color:  darkgreen;
#         }#T_4e3deece_149c_11eb_abd3_0242ac1c0002row0_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row1_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row2_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row3_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row4_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row5_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row6_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row7_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row8_col4,#T_4e3deece_149c_11eb_abd3_0242ac1c0002row9_col4{
# ...

# %%
df.head(10).style.format(format_dict).background_gradient(subset=['data science', 'machine learning'], cmap='BuGn')
# Out:
# <style  type="text/css" >
# #T_58979276_149c_11eb_abd3_0242ac1c0002row0_col1,#T_58979276_149c_11eb_abd3_0242ac1c0002row1_col1,#T_58979276_149c_11eb_abd3_0242ac1c0002row1_col2,#T_58979276_149c_11eb_abd3_0242ac1c0002row2_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_58979276_149c_11eb_abd3_0242ac1c0002row0_col2{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_58979276_149c_11eb_abd3_0242ac1c0002row2_col1,#T_58979276_149c_11eb_abd3_0242ac1c0002row5_col1,#T_58979276_149c_11eb_abd3_0242ac1c0002row6_col1{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_58979276_149c_11eb_abd3_0242ac1c0002row3_col1,#T_58979276_149c_11eb_abd3_0242ac1c0002row8_col1{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_58979276_149c_11eb_abd3_0242ac1c0002row3_col2,#T_58979276_149c_11eb_abd3_0242ac1c0002row6_col2{
# ...

# %%
data = pd.read_csv('https://raw.githubusercontent.com/drazenz/heatmap/master/autos.clean.csv')
corr = data.corr()

# %%
data.head()
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                122  alfa-romero       gas        std
# 1           3                122  alfa-romero       gas        std
# 2           1                122  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 4           2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
#    width  height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
# load the Titanic data into Pandas DataFrame using the .csv file
titanic = pd.read_csv('https://raw.githubusercontent.com/estambolieva/fast_track_to_python/master/day2/pandas/titanic_data/train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
titanic.plot.scatter(x='Age', y='Fare')

# %%
titanic.plot.scatter(x='Age', y='Sex')

# %%
titanic.plot(x='Age', y='Fare', kind="hexbin", figsize=(20,20))

# %%
titanic.Survived.value_counts().plot(kind='bar', alpha=0.9)

# %%
titanic.plot(kind= 'scatter', x='Age', y='Survived')

# %%
sns.violinplot(x=titanic.Survived, y=titanic.Age)

# %%
titanic.plot.scatter(x='Pclass', y='Fare')
# or we can write code : titanic.plot(kind='scatter',x='Pclass', y='Fare')

# %%
titanic.plot(kind='scatter',x='Pclass', y='Fare')

# %%
df= titanic.groupby('Survived').count()
df
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
df.plot.pie(y= 'Age')

# %%
df.plot.pie(y= 'Embarked')

# %%
df.plot.pie(y= 'Cabin')

# %%
import matplotlib.pyplot as plt

# %%
corr=titanic.corr()  #Survived
plt.figure(figsize=(15,15))

sns.heatmap(corr, square=True, annot=True, cmap='YlGnBu',linecolor='white')
plt.title('Correlation between features');

# %%
titanic.plot(kind='bar',x='Pclass', y='Fare')

# %%
group= titanic.groupby(['Pclass','Survived'])

pclass_survived= group.size().unstack()
sns.heatmap(pclass_survived, annot= True, fmt='d', cmap='coolwarm')

# %%
sns.violinplot(x='Sex', y='Age', hue='Survived', data= titanic, split=True)

# %%
sns.violinplot(x='Sex', y='Fare', hue='Survived', data= titanic, split=True)

# %%
sns.violinplot(x='Parch', y='SibSp', hue='Sex', data= titanic, split=True)

# %%
titanic.hist(column='Pclass', by='Survived')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0fd7b450b8>,
# ...
#       dtype=object)

# %%
# the semicolon at the end hides matplotlib's messages
titanic.hist(column='Pclass', by='Survived');

# %%
ax= titanic.hist(column='Pclass', by='Survived', sharey=True);
